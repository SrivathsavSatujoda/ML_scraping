# %%
'''
Created on Apr 3, 2017

@author: Xuebin Wei
www.lbsocial.net
Extract texts from major news media webpages 
Very rough extraction
'''
from bs4 import BeautifulSoup
import urllib.request
import re

# %%
'''
for any webpages, extract all the visible texts
'''
 
#html = urllib.request.urlopen('https://www.amazon.com/TiVo-BOLT-500-DVR-Version/product-reviews/B013X8YI5I') # put the url here
#html = urllib.request.urlopen('https://www.amazon.com/TiVo-VOX-Remote-BOLT/product-reviews/B07634QZPL') # put the url here

#html = urllib.request.urlopen('https://www.tivocommunity.com/community/index.php?threads/tivo-mini-vox-4k-reviews-and-comments-thread.554456/')

html = urllib.request.urlopen('https://www.bestbuy.com/site/reviews/tivo-bolt-vox-3tb-dvr-streaming-player-black/6115415')


    
soup = BeautifulSoup(html.read(), 'html.parser')
texts = soup.findAll(text=True)

def visible(element):
     if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
     elif re.match('<!--.*-->', str(element)):
        return False
     elif re.match('[if * <![endif]', str(element)):
        return False
     return True
visible_texts = filter(visible, texts)

'''
 write the texts into a txt file
'''
with open('bestbuy_vox.txt', 'bw') as outfile: #define the location of the output
     for text in visible_texts:
        try:
             print(text.encode('utf-8'))
 
             outfile.write(text.encode('utf-8'))
        except:
            pass
# Out:
# b'Skip to content'
# b'Free Shipping on Everything'
# b'Weekly Ad'
# b'Deal of the Day'
# b'Credit Cards'
# b'Gift Cards'
# b'Gift Ideas & Registry'
# b'Best Buy Logo'
# b'Store Locator'
# b'Cart'
# b'Products'
# b'Featured'
# b'Cyber Monday 2017'
# b'Gift Ideas'
# b'Top Tech Gifts'
# b'Special Edition Tech'
# b'4K Ultra HDTVs'
# b'Apple Watch Series 3'
# b'All Categories'
# b'Appliances'
# b'Appliances'
# b'Major Kitchen Appliances'
# b'Refrigerators'
# b'Dishwashers'
# b'Ranges, Cooktops & Wall Ovens'
# b'Range Hoods'
# b'Microwaves'
# b'Kegerators & Wine Coolers'
# b'Freezers & Ice Makers'
# b'Kitchen Appliance Packages'
# b'Laundry & Garment Care'
# b'Washers & Dryers'
# b'Laundry Packages'
# b'Irons, Steamers & Sewing Machines'
# b'Floor Care, Seasonal & Parts'
# b'Vacuum Cleaners & Floor Care'
# b'Heating, Cooling & Air Quality'
# b'Outdoor Living'
# b'Appliance Parts & Accessories'
# b'Small Kitchen Appliances'
# b'Blenders & Juicers'
# b'Coffee, Tea & Espresso'
# b'Countertop Microwaves'
# b'Mini Fridges'
# b'Mixers'
# b'Pressure Cookers & Instant Pot'
# b'Toaster & Pizza Ovens'
# b'Shop All Small Kitchen Appliances'
# b'Services & Support'
# b'Appliance Installation'
# b'Delivery & Haul Away'
# b'Recycling'
# b'Shop All Appliance Services'
# b'Deals & Outlet'
# b'Major Appliance Deals'
# b'Small Appliance Deals'
# b'Appliance Open-Box'
# b'In-Store Experience'
# b'Pacific Kitchen & Home'
# b'Samsung Open House'
# b'Close'
# b'TV & Home Theater'
# b'TV & Home Theater'
# b'TVs'
# b'Find the Perfect TV'
# b'4K Ultra HD TVs'
# b'Smart TVs'
# b'Curved TVs'
# b'OLED TVs'
# b'LED TVs'
# b'Outdoor TVs'
# b'Shop All Televisions'
# b'Audio & Video Components'
# b'Blu-ray & DVD Players'
# b'Streaming Media Players'
# b'Home Theater Systems'
# b'Sound Bars'
# b'Projectors & Screens'
# b'Home Audio Components'
# b'Wireless & Multiroom Audio'
# b'Accessories'
# b'TV Stands, Mounts & Furniture'
# b'A/V Cables & Connectors'
# b'Remote Controls'
# b'Surge Protectors & Power'
# b'HDMI Cables'
# b'Home Theater Networking'
# b'TV Antennas'
# b'Shop All Accessories'
# b'Services & Support'
# b'TV & Home Theater Services'
# b'TV & Internet Service Providers'
# b'Deals & Outlet'
# b'Top Deals on 4K TVs & HDTVs'
# b'TV & Home Theater Open-Box'
# b'In-Store Experience'
# b'Magnolia Home Theater'
# b'Samsung Entertainment Experience'
# b'Sony Experience Shop'
# b'LG Experience'
# b'Close'
# b'Computers & Tablets'
# b'Computers & Tablets'
# b'Computers'
# b'Laptops'
# b'Desktops & All-in-One Computers'
# b'2-in-1s'
# b'PC Gaming & Virtual Reality'
# b'PC Gaming'
# b'Gaming Accessories & Peripherals'
# b'Virtual Reality'
# b'Computer Accessories'
# b'Monitors'
# b'Printers, Ink & Toner'
# b'Hard Drives & Storage'
# b'Wi-Fi & Networking'
# b'Software'
# b'Computer Cards & Components'
# b'Shop All Computer Accessories'
# b'Tablets & Accessories'
# b'Tablets'
# b"Kids' Tablets"
# b'E-Readers & Accessories'
# b'Services & Support'
# b'Computer & Tablet Services'
# b'AppleCare Protection'
# b'Easy Replenish Ink'
# b'Deals & Outlet'
# b'Computer Deals'
# b'Tablet Deals'
# b'Computers & Tablets Open-Box'
# b'Computers & Tablets Refurbished'
# b'In-Store Experience'
# b'Apple Store'
# b'Samsung Experience Store'
# b'Close'
# b'Cameras & Camcorders'
# b'Cameras & Camcorders'
# b'Cameras & Lenses'
# b'Digital SLR Cameras'
# b'Mirrorless Cameras'
# b'Camera Lenses'
# b'Point & Shoot Cameras'
# b'Instant Print Cameras'
# b'Shop All Digital Cameras'
# b'Drones'
# b'Drones & Accessories'
# b'Camcorders'
# b'Action Camcorders'
# b'Traditional Camcorders'
# b'360 Degree Cameras'
# b'Shop All Camcorders'
# b'Related Categories'
# b'Security Cameras & Systems'
# b'Instant Photo Printers'
# b'Binoculars, Telescopes & Optics'
# b'Accessories'
# b'Memory Cards'
# b'Camera Bags & Cases'
# b'Tripods & Monopods'
# b'Flashes & Lighting'
# b'Lens Filters'
# b'Camera Batteries & Chargers'
# b'Camcorder Accessories'
# b'Instant Print Film'
# b'Shop All Camera Accessories'
# b'Services & Support'
# b'Camera & Camcorder Protection'
# b'Shop All Camera & Camcorder Services'
# b'Deals & Outlet'
# b'Camera & Camcorder Deals'
# b'Camera & Camcorder Open-Box'
# b'Camera & Camcorder Clearance'
# b'In-Store Experience'
# b'Camera Experience Shop'
# b'Close'
# b'Cell Phones'
# b'Cell Phones'
# b'Shop by Carrier'
# b'Verizon'
# b'AT&T'
# b'Sprint'
# b'Shop by Phone'
# b'Samsung Galaxy'
# b'Phones with Plans'
# b'Prepaid Phones'
# b'Unlocked Phones'
# b'Refurbished & Pre-Owned Phones'
# b'Cell Phone Accessories'
# b'Samsung Galaxy Accessories'
# b'Cell Phone Cases & Clips'
# b'Wireless Chargers & Cases'
# b'Portable Chargers & Power Packs'
# b'Instant Photo Printers'
# b'Screen Protectors'
# b'Shop All Accessories'
# b'Services & Support'
# b'Cell Phone Services'
# b'AppleCare+ for iPhone'
# b'My Best Buy Mobile'
# b'Deals & Outlet'
# b'Cell Phone Deals'
# b'Cell Phone Refurbished & Pre-Owned'
# b'Trade-In & Upgrade'
# b'Cell Phone Trade-In'
# b'Cell Phone Upgrade Checker'
# b'Close'
# b'Audio'
# b'Audio'
# b'Home Audio'
# b'Home Theater Systems'
# b'Receivers & Amplifiers'
# b'Speakers'
# b'Turntables'
# b'CD Players'
# b'Stereo Shelf Systems'
# b'Sound Bars'
# b'High-Resolution Audio'
# b'Magnolia: Premium Audio'
# b'Bring superior sound to your home theater.'
# b'Home Audio Accessories'
# b'Portable Audio'
# b'Headphones'
# b'Portable Speakers'
# b'Radios, Boomboxes & Speaker Docks'
# b'More Audio'
# b'Car Audio'
# b'Marine Audio'
# b'Musical Instruments'
# b'Wireless & Multiroom Audio'
# b'Wireless Multiroom Audio Systems'
# b'Multiroom Receivers'
# b'Bluetooth & Wireless Speakers'
# b'Smart Speakers'
# b'Bluetooth & Wi-Fi speakers with voice assistants.'
# b'Wireless Headphones'
# b'Shop All Wireless Audio'
# b'Services & Support'
# b'Portable Audio Services'
# b'TV & Home Theater Services'
# b'Deals & Outlet'
# b'Wireless Audio Deals'
# b'Home Audio Deals'
# b'Audio Open-Box & Refurbished'
# b'Audio Clearance'
# b'In-Store Experience'
# b'Magnolia Home Theater'
# b'Close'
# b'Video Games'
# b'Video Games'
# b'Xbox One'
# b'Xbox One Consoles'
# b'Xbox One Games'
# b'Xbox One Accessories'
# b'Shop All Xbox One'
# b'Nintendo Switch'
# b'Nintendo Switch Consoles'
# b'Nintendo Switch Games'
# b'Nintendo Switch Accessories'
# b'Shop All Nintendo Switch'
# b'PlayStation 4'
# b'PlayStation 4 Consoles'
# b'PlayStation 4 Games'
# b'PlayStation 4 Accessories'
# b'PlayStation VR'
# b'Shop All PlayStation 4'
# b'More Gaming'
# b'Nintendo 3DS'
# b'Retro Gaming'
# b'SNES, Sega Genesis, Atari'
# b'PC Gaming'
# b'Digital Gaming'
# b'Gaming Headsets'
# b'All Gaming Accessories'
# b'Licensed Collectibles'
# b'Services & Support'
# b'Video Game Trade-In'
# b'Video Game Services'
# b'Deals & Outlet'
# b'Video Games Pre-Owned & Refurbished'
# b'Video Game Deals'
# b'Video Games Clearance'
# b"Gamer's Club Unlocked"
# b'Learn More'
# b'Sign-Up'
# b'Member Offers'
# b'Close'
# b'Movies & Music'
# b'Movies & Music'
# b'Movies & TV Shows'
# b'Pre-Orders'
# b'New Releases'
# b'4K Ultra HD Blu-ray Discs'
# b'Blu-ray Discs'
# b'Blu-ray 3D'
# b'SteelBooks'
# b'DVDs'
# b'TV Shows'
# b'Shop All Movies & TV Shows'
# b'Music'
# b'New Releases'
# b'Pre-Orders'
# b'CDs'
# b'Vinyl'
# b'Musical Instruments'
# b'Shop All Music'
# b'Shop by Franchise'
# b'Star Wars'
# b'Marvel'
# b'DC Comics'
# b'Disney'
# b'Pixar'
# b'Transformers'
# b'X-Men'
# b'Game of Thrones'
# b'Shop All Franchises'
# b'Deals & Outlet'
# b'Movies & TV Shows Deals'
# b'Music Deals'
# b'Entertainment Gift Cards'
# b'App Store & iTunes Gift Cards'
# b'Spotify Gift Cards'
# b'Google Gift Cards'
# b'Dining Gift Cards'
# b'Shop All Gift Cards'
# b'Close'
# b'Car Electronics & GPS'
# b'Car Electronics & GPS'
# b'Car Audio'
# b'Car Stereo Receivers'
# b'Car Speakers'
# b'Car Subwoofers & Enclosures'
# b'Car Amplifiers'
# b'Car Equalizers & Processors'
# b'Smartphone & iPod Car Connectors'
# b'Satellite Radios'
# b'Car Installation Parts & Accessories'
# b'Shop All Car Audio'
# b'Car Security & Convenience'
# b'Remote Starters & Keyless Entry'
# b'Radar Detectors'
# b'Vehicle Diagnostics'
# b'Remote Transmitters'
# b'Car Lights & Accessories'
# b'Car Video & GPS'
# b'GPS Navigation & Accessories'
# b'Back-Up & Dash Cameras'
# b'Car Video & DVD Players'
# b'Other Categories'
# b'Marine & Powersports'
# b'Services & Support'
# b'Car Electronics Professional Installation'
# b'Deals & Outlet'
# b'Car Electronics & GPS Deals'
# b'Car Electronics & GPS Outlet'
# b'Close'
# b'Wearable Technology'
# b'Wearable Technology'
# b'Action Camcorders'
# b'Activity Trackers & Pedometers'
# b'Apple Watch'
# b'Fitness & GPS Watches'
# b'Headphones'
# b'Pet Tracking Devices'
# b'Smart Sports Equipment'
# b'Smart Tracker Tags'
# b'Smartwatches & Accessories'
# b'Virtual Reality'
# b'Featured Brands'
# b'Apple'
# b'Beats'
# b'Bose'
# b'Fitbit'
# b'Garmin'
# b'Samsung'
# b'Services & Support'
# b'Wearable Technology Services'
# b'AppleCare+ for Apple Watch'
# b'Deals & Outlet'
# b'Wearable Technology Deals'
# b'Wearable Technology Open-Box'
# b'Close'
# b'Health, Fitness & Beauty'
# b'Health, Fitness & Beauty'
# b'Health & Fitness'
# b'Activity Trackers & Pedometers'
# b'Apple Watch'
# b'Assistive Technology'
# b'Baby & Prenatal Care'
# b'Fitness & GPS Watches'
# b'Fitness Videos & Software'
# b'Health Monitoring & Testing'
# b'Headphones'
# b'Scales'
# b'Smart Sports Equipment'
# b'Smartwatches & Accessories'
# b'Sports & Outdoor Recreation'
# b'Sports Fan Shop'
# b'Health & Fitness Accessories'
# b'Personal Care & Beauty'
# b'Shavers, Trimmers & Groomers'
# b'Hair Care'
# b'Oral Care'
# b'Massagers & Spa'
# b'Skin Care'
# b'Mirrors'
# b'Light Therapy'
# b'Essential Oil Diffusers & Oils'
# b'Shop All Personal Care & Beauty'
# b'Services & Support'
# b'Wearable Technology Services'
# b'Deals & Outlet'
# b'Personal Care & Beauty Deals'
# b'Health Fitness & Beauty Open-Box'
# b'Personal Care & Beauty Clearance'
# b'Close'
# b'Home, Garage & Office'
# b'Home, Garage & Office'
# b'Home'
# b'Appliances'
# b'Furniture & Decor'
# b'Household Essentials'
# b'Wi-Fi & Networking'
# b'Outdoor Living'
# b'Pet Supplies & Technology'
# b'Security Cameras & Surveillance'
# b'Vacuum Cleaners & Floor Care'
# b'Garage'
# b'Autonomous Lawn Care'
# b'Batteries & Power'
# b'Garage Door Openers'
# b'Garage Storage & Organization'
# b'Sprinkler & Irrigation Controls'
# b'Tool Chests & Parts Racks'
# b'Workbenches & Stools'
# b'Shop All Garage'
# b'Office'
# b'Printers, Ink & Toner'
# b'Scanners, Faxes & Copiers'
# b'Telephones & Communication'
# b'Office Furniture'
# b'Projectors & Screens'
# b'Business Software'
# b'Shop All Office Electronics'
# b'Services & Support'
# b'Smart Home Services'
# b'TV & Internet Service Providers'
# b'Vivint Smart Home'
# b'Deals & Outlet'
# b'Office Open-Box'
# b'Office Refurbished'
# b'Close'
# b'Smart Home, Security & Wi-Fi'
# b'Smart Home, Security & Wi-Fi'
# b'Smart Home'
# b'Voice Assistants'
# b'Smart Lighting'
# b'Smart Switches & Outlets'
# b'Smart & Wi-Fi Thermostats'
# b'Smart Locks & Garage Control'
# b'Sprinkler & Irrigation Control'
# b'Pet Supplies & Technology'
# b'Home Security & Surveillance'
# b'Security Cameras & Surveillance'
# b'Wireless Doorbell Cameras'
# b'Motion Sensors & Detectors'
# b'Smoke & Carbon Monoxide Detectors'
# b'Home Automation Systems & Kits'
# b'Baby Monitors'
# b'Wi-Fi & Networking'
# b'Routers'
# b'Whole Home Wi-Fi'
# b'Modems'
# b'Network Switches'
# b'Network Security & Firewall Devices'
# b'Wi-Fi Extenders'
# b'USB Wi-Fi Adapters'
# b'Shop by Compatibility'
# b'Apple HomeKit'
# b'Amazon Alexa'
# b'Google Assistant'
# b'Nest'
# b'Philips Hue'
# b'Samsung SmartThings'
# b'Shop by Brand'
# b'Arlo'
# b'Google Home'
# b'Nest'
# b'Philips Hue'
# b'Vivint Smart Home'
# b'Close'
# b'Drones, Toys & Collectibles'
# b'Drones, Toys & Collectibles'
# b'Drones & Accessories'
# b'Drones with Cameras'
# b'Toy Drones'
# b'Drone Accessories'
# b'Shop All Drones & Accessories'
# b'Rideables'
# b'Self-Balancing Scooters'
# b'Skateboards & Longboards'
# b'Shop All Rideables'
# b'Toys'
# b'STEM & Educational Toys'
# b'Dolls'
# b'Action Figures'
# b'Building Sets & Blocks'
# b'App-Enabled & Remote Control Toys'
# b'Sports & Outdoor Play'
# b"Kids' Electronics"
# b'Interactive Pets'
# b'Shop All Toys'
# b'Licensed Collectibles'
# b'Statue Collectibles'
# b'Stuffed Animals & Plush Collectibles'
# b'Licensed Electronics'
# b'Shop All Licensed Collectibles'
# b'Games, Puzzles & Cards'
# b'Board Games'
# b'Puzzles'
# b'Cards, Poker & Casino Games'
# b'Shop All Games'
# b'Gifts'
# b'Birthday Gifts'
# b'Gifts for Kids'
# b'Gifts for Teens'
# b'Shop All Gifts'
# b'Deals & Outlet'
# b'Drones, Toys & Collectibles Deals'
# b'Drones, Toys & Collectibles Clearance'
# b'Education'
# b'Solutions & Resources'
# b'Close'
# b'Best Buy Outlet'
# b'Close'
# b'FREE SHIPPING ON EVERYTHING'
# b'FAST STORE PICKUP'
# b'PRICE MATCH GUARANTEE'
# b'Brands'
# b'Brand Shops'
# b'Apple'
# b'Samsung'
# b'Sony'
# b'Microsoft'
# b'Intel'
# b'Shop all brands'
# b'Specialty Shops'
# b'Magnolia Home Theater'
# b"Online or in-store, we'll help you create the ultimate home entertainment experience."
# b'Pacific Kitchen & Home'
# b'Premium appliance brands and expert service available inside select Best Buy stores.'
# b'Camera Experience Shop'
# b'Shop a wider selection, talk to a camera expert and try before you buy at select Best Buy stores.'
# b'Close'
# b'FREE SHIPPING ON EVERYTHING'
# b'FAST STORE PICKUP'
# b'PRICE MATCH GUARANTEE'
# b'Deals'
# b'Hottest Deals'
# b'Great deals happening right now.'
# b'Weekly Ad'
# b"This week's best deals, all in one place."
# b'Deal of the Day'
# b'A great deal, today only.'
# b'Member Offers'
# b'Deals designed especially for you.'
# b'Best Buy Outlet'
# b'Clearance, open-box, refurbished and pre-owned.'
# b'Student Hub'
# b'Student Deals & Back to School'
# b'Deals by Category'
# b'Cyber Monday 2017'
# b'TVs'
# b'Laptops & Computers'
# b'Tablets & E-Readers'
# b'Video Games & VR'
# b'Headphones & Speakers'
# b'Cell Phones'
# b'Home Theater & Audio'
# b'Streaming Devices & Video'
# b'Smart Home & Security'
# b'Drones & Toys'
# b'Cameras & Camcorders'
# b'Wearables & Smartwatches'
# b'Major Appliances'
# b'Small Appliances'
# b'Movies, TV Shows & Music'
# b'Printers & Home Office'
# b'Car Electronics & GPS'
# b'Clearance & More'
# b'Close'
# b'FREE SHIPPING ON EVERYTHING'
# b'FAST STORE PICKUP'
# b'PRICE MATCH GUARANTEE'
# b'Services'
# b'Geek Squad Support'
# b'Tech Help & Inspiration'
# b'Chat with a Geek Squad Agent'
# b'Schedule a Service'
# b'Track Your Repair'
# b'Manage Your Appointment'
# b'Geek Squad Plans & Services'
# b'Geek Squad 24/7 Support'
# b'Protection Plans'
# b'Computer & Tablet Services'
# b'TV & Home Theater Services'
# b'Car Electronics Professional Install'
# b'Appliance Services'
# b'Smart Home Services'
# b'Camera & Camcorder Services'
# b'Cell Phone Services'
# b'See All Geek Squad Services'
# b'Additional Services'
# b'Find Replacement Parts'
# b'Trade-In Program'
# b'Recycle Your Old Products'
# b'Customer Service'
# b'In-Home Consultation'
# b'AppleCare'
# b'AppleCare Protection & AppleCare+'
# b'Close'
# b'FREE SHIPPING ON EVERYTHING'
# b'FAST STORE PICKUP'
# b'PRICE MATCH GUARANTEE'
# b'Account'
# b'Close'
# b'Welcome!'
# b'Sign In'
# b'Create one'
# b'Your Orders & More'
# b'Track your package'
# b'Purchase History'
# b'Learn About Easy Replenish'
# b'\xe2\x84\xa2'
# b'Digital Library'
# b'Recommendations for You'
# b'Your Rewards'
# b'Rewards Overview'
# b'Services & Support'
# b'Your Plans & Memberships'
# b'Your Service History'
# b'Track Your Repair'
# b'Manage Your Account'
# b'Account Home'
# b'Account Settings'
# b'Credit Cards'
# b'E-mail Address'
# b'Shipping Address'
# b'Phone Number'
# b'Communication Preferences'
# b'Store Pickup Options'
# b'Change Password'
# b'Sign In'
# b'Create a BestBuy.com account'
# b'\xc2\xa0'
# b'Rewards on Best Buy purchases'
# b'\xc2\xa0'
# b'Enhanced online and store purchase information'
# b'\xc2\xa0'
# b'Access to your protection plans and services'
# b'Shopping History'
# b'Order Status'
# b'Saved Items'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Best Buy'
# b'TV & Home Theater'
# b'Streaming Media Players'
# b'All Streaming Media Players'
# b'Product Details'
# b'Customer Ratings & Reviews'
# b'TiVo - BOLT VOX 3TB DVR & Streaming Player - Black'
# b'Model:'
# b'TCD849300V'
# b'SKU:'
# b'6115415'
# b'$'
# b'499.98'
# b'loading'
# b'Write a Review'
# b'Overall Customer Rating'
# b'4.5'
# b'(2 Reviews)'
# b'100%'
# b'of customers recommend this product.'
# b'pros'
# b'set up'
# b'('
# b'1'
# b')'
# b'(Interface, etc.) I am happy with the '
# b'.'
# b'\xe2\x80\x93'
# b'akwoolf'
# b'See all reviews that mention '
# b'set up'
# b'pro'
# b'(Interface, etc.) I am happy with the '
# b'.'
# b'\xe2\x80\x93'
# b'akwoolf'
# b'See all reviews that mention '
# b'set up'
# b'pro'
# b'cons'
# b"Looks like there aren't enough "
# b'Customer Ratings & Reviews'
# b'Search'
# b'Clear Search Text'
# b'Filter:'
# b'Ratings, Verified Purchase'
# b'Sort by:'
# b'Most Helpful'
# b'Most Recent'
# b'Oldest'
# b'Highest Rating'
# b'Lowest Rating'
# b'Verified Purchase'
# b'(1 Review)'
# b'Reviewer Rating 5 out of 5 stars'
# b'5'
# b'(1 Review)'
# b'Reviewer Rating 4 out of 5 stars'
# b'4'
# b'(1 Review)'
# b'Reviewer Rating 3 out of 5 stars'
# b'3'
# b'(0 Reviews)'
# b'Reviewer Rating 2 out of 5 stars'
# b'2'
# b'(0 Reviews)'
# b'Reviewer Rating 1 out of 5 stars'
# b'1'
# b'(0 Reviews)'
# b'1-2 of 2 Reviews'
# b'Customer Rating & Reviews'
# b'See all reviews'
# b'akwoolf'
# b'Reviewer Rating 5 out of 5 stars '
# b'5'
# b'Tivo Noob'
# b'November 7, 2017'
# b"I am new to the Tivo world and have no point of comparison as to how previous versions operated. (Interface, etc.) I am happy with the ease of installation. Initially I had it set up as Ethernet only, and then changed to Ethernet and MoCA. I spent about 30 minutes setting up the unit, updating, etc. I also spent about 20 minutes on the phone with Spectrum (Former Charter area) setting up my cable card. That process wasn't as painful as I expected. I obtained 2 cable cards just in case one of them was inoperative. (My first card - an Arris - worked fine) I spent another 20 minutes setting up my app accounts. I signed into Hulu, Netflix, Amazon, Epix, HBOGo, etc. (all of which I have access to) My initial experience over 10 hours of use has been rather enjoyable. The box is very responsive, the apps work, and the setup was straight-forward and easy for a Tivo noobie such as myself. I also ordered 3 of the new Tivo mini's. The setup went well initially with those. Everything was fine (MoCA setup, etc.) until the last step where the mini needs to communicate with the main DVR. I couldn't get it to communicate. I ended up having to call tech support (India) and they had me walk through some basic steps that seemed to make no sense to me. As a rookie, I played along as they had me unplug the device a few times, etc. None of this worked. After about 30 minutes, the support rep was able to get it to work. I asked what she had to do and she mentioned something about allowing content sharing on my account... My initial rating for Tivo Bolt Vox 3TB is 5 stars. I am withholding judgment initially on the mini, but I will most likely rate them as four stars, as they were not quite as simple to configure as I felt they should be. (as child units)"
# b'I would\xc2\xa0recommend this to a friend'
# b'Helpful ('
# b'1'
# b')'
# b'Unhelpful ('
# b'0'
# b')'
# b'Report'
# b'Post Comment'
# b'Patrick'
# b'Reviewer Rating 4 out of 5 stars '
# b'4'
# b"New Gui isn't bad"
# b'November 24, 2017'
# b'This Tivo uses the new Hydra GUI. If you are a long time Tivo user, it is something that you will have to become accustomed to. If you are a new user, things should be fine. As with anything new, it takes time to learn all the little things that you need to know.'
# b'I would\xc2\xa0recommend this to a friend'
# b'Helpful ('
# b'0'
# b')'
# b'Unhelpful ('
# b'0'
# b')'
# b'Report'
# b'Post Comment'
# b'Page 1, showing'
# b'1-2 of  2  Reviews'
# b'See All Reviews'
# b'Get the Latest Deals & More'
# b'BEST BUY APP'
# b'Learn more \xe2\x80\xba'
# b'My Best Buy \xe2\x80\xba'
# b'View Points & Certificates'
# b'Member Offers'
# b'Sign in or Create Account'
# b'Credit Cards \xe2\x80\xba'
# b'Make Payment/Check Balance'
# b'Credit Card Offers'
# b'Apply Now'
# b'Orders & Returns \xe2\x80\xba'
# b'Order Status'
# b'Shipping, Delivery & Store Pickup'
# b'Return & Exchange Promise'
# b'Price Match Guarantee'
# b'Pay with Points'
# b'Support & Services \xe2\x80\xba'
# b'Customer Service'
# b'Protection Plans'
# b'Schedule a Service'
# b'Trade-In Program'
# b'Product Recalls'
# b'Partnerships \xe2\x80\xba'
# b'Affiliate Program'
# b'Developers'
# b'Best Buy Ignite'
# b'Best Buy for Education'
# b'Best Buy Direct'
# b'Advertise with Us'
# b'Corporate Information'
# b'Forums, Blog & More'
# b'Careers'
# b'Accessibility'
# b'Terms and Conditions'
# b'Privacy'
# b'Interest-Based Ads'
# b'California Privacy Rights'
# b'CA Supply Chain Transparency Act'
# b'Facebook'
# b'Twitter'
# b'Instagram'
# b'Pinterest'
# b'Mobile Site'
# b'Give Feedback'
# b'Prices and offers are subject to change. \xc2\xa9 2017 Best Buy. All rights reserved. BEST BUY, the BEST BUY logo, the tag design, MY BEST BUY, and BESTBUY.COM are trademarks of Best Buy and its affiliated companies.'

# %%
'''
for any webpages, extract all the visible texts
'''
 
# html = urllib.request.urlopen('') # put the url here
# 
# soup = BeautifulSoup(html.read(), 'html.parser')
# texts = soup.findAll(text=True)

# def visible(element):
#     if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
#         return False
#     elif re.match('<!--.*-->', str(element)):
#         return False
#     elif re.match('[if * <![endif]', str(element)):
#         return False
#     return True
# 
# visible_texts = filter(visible, texts)
# 
# '''
# write the texts into a txt file
# '''
# with open('news.txt', 'bw') as outfile: #define the location of the output
#     for text in visible_texts:
#         try:
#             print(text.encode('utf-8'))
# 
#             outfile.write(text.encode('utf-8'))
#         except:
#             pass
            
            
'''
Extract text from fox news
'''
# html = urllib.request.urlopen('http://www.foxnews.com/politics/2017/04/04/'
#                               'susan-rice-claimed-ignorance-on-trump-team'
#                               '-surveillance-before-role-in-unmasking-revealed.html') # fill in the url
#   
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_article_text in soup.find_all('div',class_ = 'article-text'):
# #     print (div_article_text)
#     for p in div_article_text.find_all('p'):
#         print (p.text)
        
'''
Extract text from cnn
'''
# html = urllib.request.urlopen('http://www.cnn.com/2017/04/04/middleeast/'
#                               'idlib-syria-attack/index.html') # fill in the url
#    
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_body_paragraph in soup.find_all('div',class_ = 'zn-body__paragraph'):
#     print (div_body_paragraph.text)

'''
Extract text from new york time
'''
# import requests
# html = requests.get('https://www.nytimes.com/2017/04/03/us/'
#                               'justice-department-jeff-sessions-baltimore-police.html?_r=0') # fill in the url
#   
# soup = BeautifulSoup(html.content, 'html.parser')
# print (soup.title.text)
# for p_story_body_text in soup.find_all('p',class_ = 'story-body-text story-content'):
#     print (p_story_body_text.text)

'''
Extract text from huffingtonpost
'''
# html = urllib.request.urlopen('http://www.huffingtonpost.com/entry/gop-health-care-deal'
#                               '-pre-existing-conditions_us_58e39db7e4b03a26a365fdf6?') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_text in soup.find_all('div',class_ = 'content-list-component bn-content-list-text text'):
#     for p in div_text.find_all('p'):
#         print (p.text.encode('utf-8'))
'''
Extract text from yahoo
'''

# html = urllib.request.urlopen('https://www.yahoo.com/news/devin-nunes-returns-'
#                               'home-to-protests-over-his-trump-ties-155939039.html') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for article in soup.find_all('article'):
#     for div in article.find_all('div'):
#         for p in div.find_all('p'):
#             print (p.text)

'''
Extract text from nbcnews
'''

# html = urllib.request.urlopen('http://www.nbcnews.com/news/world/syria-chemical-attack-'
#                               'reportedly-kills-dozens-idlib-province-n742416') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div in soup.find_all('div', class_ = 'article-body'):
#     for p in div.find_all('p'):
#         print (p.text)

'''
Extract text from washingtonpost
'''

# html = urllib.request.urlopen('https://www.washingtonpost.com/world/national-security/blackwater-founder-held-secret-seychelles-meeting-to-establish-trump-putin-back-channel/2017/04/03/95908a08-1648-11e7-ada0-1489b735b3a3_story.html?hpid=hp_hp-top-table-main'
#                               '_seychelles-0438pm-1%3Ahomepage%2Fstory&utm_term=.b9f05806a056') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for article in soup.find_all('article', itemprop = 'articleBody'):
#     for p in article.find_all('p'):
#         print (p.text.encode('utf-8'))
